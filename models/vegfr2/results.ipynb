# %% [markdown]
# ## Results interpretation and model selection

# %%
import pandas as pd

# %%
results1 = pd.read_csv('data/annresults_32.csv')
results1
# Out:
#      # of Nodes 3  Epochs  Batch size  l2_2  l2_3  Train loss  Test loss  \
# 0              32     150           6  0.05  0.00    6.533290   6.560819
# 1              64     100           6  0.05  0.00    6.533290   6.560819
# 2              64     100           6  0.03  0.07    6.533290   6.560819
# 3              64     100           6  0.03  0.05    6.533290   6.560819
# 4              64     100           6  0.03  0.03    6.533290   6.560819
# ..            ...     ...         ...   ...   ...         ...        ...
# 214            64      50           2  0.07  0.07    0.753138   0.865692
# 215            64      50           2  0.05  0.03    0.719153   0.858226
# 216            64      50           2  0.05  0.05    0.745524   0.858139
# 217            64      50           2  0.03  0.03    0.734300   0.855975
# 218            32      50           2  0.07  0.00    0.730725   0.852876
#
#             r2
# 0   -27.203229
# 1   -27.203229
# 2   -27.203229
# 3   -27.203229
# ...

# %%
results2 = pd.read_csv('data/annresults_64.csv')
results2
# Out:
#      # of Nodes 3  Epochs  Batch size  l2_2  l2_3  Train loss  Test loss  \
# 0              64      50           2  0.03  0.03    0.734300   0.855975
# 1              64      50           2  0.05  0.05    0.745524   0.858139
# 2              64      50           2  0.05  0.03    0.719153   0.858226
# 3              64      50           2  0.03  0.00    0.736160   0.864740
# 4              64      50           2  0.07  0.07    0.753138   0.865692
# ..            ...     ...         ...   ...   ...         ...        ...
# 106            64     150           2  0.05  0.05    6.533290   6.560819
# 107            64      50           4  0.05  0.00    6.533290   6.560819
# 108            64      50           4  0.03  0.05    6.533290   6.560819
# 109            64      50           2  0.07  0.03    6.533290   6.560819
# 110            32      50           2  0.03  0.05    6.533290   6.560819
#
#             r2
# 0     0.244420
# 1     0.241578
# 2     0.230979
# 3     0.221919
# ...

# %%
results3 = pd.read_csv('data/results_nolayer3.csv')
results3.drop(results3.columns[results3.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
results3
# Out:
#     # of Nodes 3  Epochs  Batch size  l2_2  l2_3  Train loss  Test loss  \
# 0              0     150           6  0.03     0    0.533064   0.816155
# 1              0     150           2  0.07     0    0.597592   0.817404
# 2              0     150           6  0.05     0    0.547634   0.817605
# 3              0     150           2  0.03     0    0.566058   0.815310
# 4              0      50           6  0.07     0    0.659924   0.824970
# 5              0     100           4  0.07     0    0.584366   0.802526
# 6              0     150           4  0.07     0    0.541711   0.806019
# 7              0     100           2  0.05     0    0.578047   0.800625
# 8              0     150           2  0.05     0    0.550276   0.813433
# 9              0     150           4  0.03     0    0.506330   0.795130
# 10             0     100           4  0.05     0    0.570616   0.796376
# 11             0     150           4  0.05     0    0.535923   0.797589
# ...

# %%
results3.to_csv('data/annresults_0.csv',index = False)
